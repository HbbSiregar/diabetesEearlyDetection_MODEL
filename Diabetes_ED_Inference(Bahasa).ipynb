# %%
# Import libraries
import pandas as pd
import pickle

# %%
# #Load Model Diabetes Early Detection RF before tuning
# with open("ModelBeforeTuning.pkl", "rb") as model:
#     model = pickle.load(model)

# %%
#Load Model Diabetes Early Detection
with open("model_Diabetes_Early_Detection.pkl", "rb") as model:
    model = pickle.load(model)

# %%
#Data Inference
dataInf = {
    'age':                  [65, 16, 30, 35],
    'gender':               ['Male', 'Male', 'Female', 'Female'],
    'polyuria':             ['No', 'Yes', 'Yes', 'No'],
    'polydipsia':           ['No', 'Yes', 'Yes', 'No'],
    'sudden_weight_loss':   ['No', 'Yes', 'No', 'No'],
    'weakness':             ['No', 'Yes', 'Yes', 'No'],
    'polyphagia':           ['No', 'Yes', 'No', 'No'],
    'genital_thrush':       ['No', 'Yes', 'Yes', 'No'],
    'visual_blurring':      ['No', 'Yes', 'No', 'No'],
    'itching':              ['No', 'Yes', 'No', 'No'],
    'irritability':         ['No', 'Yes', 'No', 'No'],
    'delayed_healing':      ['No', 'Yes', 'No', 'No'],
    'partial_paresis':      ['No', 'Yes', 'No', 'No'],
    'muscle_stiffness':     ['No', 'Yes', 'No', 'No'],
    'alopecia':             ['No', 'Yes', 'No', 'No'],
    'obesity':              ['No', 'No',  'No', 'No']
}

df_inf = pd.DataFrame(dataInf)

df_inf
# Out:
#    age  gender polyuria polydipsia sudden_weight_loss weakness polyphagia  \
# 0   65    Male       No         No                 No       No         No
# 1   16    Male      Yes        Yes                Yes      Yes        Yes
# 2   30  Female      Yes        Yes                 No      Yes         No
# 3   35  Female       No         No                 No       No         No
#
#   genital_thrush visual_blurring itching irritability delayed_healing  \
# 0             No              No      No           No              No
# 1            Yes             Yes     Yes          Yes             Yes
# 2            Yes              No      No           No              No
# 3             No              No      No           No              No
#
#   partial_paresis muscle_stiffness alopecia obesity
# 0              No               No       No      No
# 1             Yes              Yes      Yes      No
# 2              No               No       No      No
# ...

# %%
#cek prediksi model
pred_inf = model.predict(df_inf)
pred_inf
# Out:
# array([0, 1, 1, 1])

# %%
#Menambahkan kolom class yang perisi prediksi model
df_inf['class'] = pred_inf

# %%
#show_dataframe
df_inf
# Out:
#    age  gender polyuria polydipsia sudden_weight_loss weakness polyphagia  \
# 0   65    Male       No         No                 No       No         No
# 1   16    Male      Yes        Yes                Yes      Yes        Yes
# 2   30  Female      Yes        Yes                 No      Yes         No
# 3   35  Female       No         No                 No       No         No
#
#   genital_thrush visual_blurring itching irritability delayed_healing  \
# 0             No              No      No           No              No
# 1            Yes             Yes     Yes          Yes             Yes
# 2            Yes              No      No           No              No
# 3             No              No      No           No              No
#
#   partial_paresis muscle_stiffness alopecia obesity  class
# 0              No               No       No      No      0
# 1             Yes              Yes      Yes      No      1
# 2              No               No       No      No      1
# ...

# %% [markdown]
# **KESIMPULAN INFERENCE**

# %% [markdown]
# - Model berhasil sukses menangkap kelas positif dan negatif
# - Gejala yang sangat berpengaruh ada polyuria, polydipsia, dan muscle stifness. Kalau salah satu ketiganya yes dan yang lain no, maka tetap positif diabetes
# - Pada gender male model berhasil menangkap kelas negatif dan positif
# - Pada gender female diatas umur 34, model gagal menangkap kelas negatif walaupun gejalanya sudah "No" semua
# - Diperlukan dataset yang lebih besar lagi karena saya sudah melakukan hyperparameter dan hasilnya cuma naik 1 angka untuk umur female, naik ke 34 dari 33 dalam mendeteksi kelas negatif di Gender Female
# - Untuk gender male tidak ada masalah
